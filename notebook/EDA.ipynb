# %% [markdown]
# ## 1. Import Libraries

# %%
# !pip install wordcloud

# %%
import numpy as np         # For numerical computing
import pandas as pd        # For data manipulation and analysis
import seaborn as sns      # For statistical data visualization
import matplotlib.pyplot as plt   # For creating plots and charts
import eda_helper_functions      # Assuming this is a custom module for EDA helper functions
from sklearn.ensemble import IsolationForest

# %% [markdown]
# ## 2. Read the Training Data

# %%
file_path = "/Users/akshitanand/Desktop/flight-price-prediction/data/Trainf.csv"

train = pd.read_csv(file_path)
train
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0          Jet Airways      2019-06-21    Mumbai   Hyderabad  10:20:00
# 1            Air India      2019-05-18     Delhi      Cochin  09:00:00
# 2            Air India      2019-06-12   Kolkata    Banglore  09:10:00
# 3              Vistara      2019-04-01   Kolkata    Banglore  20:20:00
# 4              Vistara      2019-06-06   Kolkata    Banglore  17:00:00
# ..                 ...             ...       ...         ...       ...
# 635           Air Asia      2019-04-12  Banglore       Delhi  04:55:00
# 636        Jet Airways      2019-05-09   Kolkata    Banglore  09:35:00
# 637             Indigo      2019-05-15  Banglore       Delhi  06:05:00
# 638  Multiple Carriers      2019-05-15     Delhi      Cochin  08:45:00
# 639        Jet Airways      2019-05-21   Kolkata    Banglore  20:00:00
#
#     arrival_time  duration  total_stops              additional_info  price
# ...

# %%
train.dtypes
# Out:
# airline             object
# date_of_journey     object
# source              object
# destination         object
# dep_time            object
# arrival_time        object
# duration             int64
# total_stops        float64
# additional_info     object
# price                int64
# dtype: object

# %%
train.assign(**{
    col: pd.to_datetime(train[col], errors='coerce', format='%Y-%m-%d %H:%M:%S') 
         for col in ["date_of_journey", "dep_time", "arrival_time"]
})
# Out:
#                airline date_of_journey    source destination dep_time  \
# 0          Jet Airways             NaT    Mumbai   Hyderabad      NaT
# 1            Air India             NaT     Delhi      Cochin      NaT
# 2            Air India             NaT   Kolkata    Banglore      NaT
# 3              Vistara             NaT   Kolkata    Banglore      NaT
# 4              Vistara             NaT   Kolkata    Banglore      NaT
# ..                 ...             ...       ...         ...      ...
# 635           Air Asia             NaT  Banglore       Delhi      NaT
# 636        Jet Airways             NaT   Kolkata    Banglore      NaT
# 637             Indigo             NaT  Banglore       Delhi      NaT
# 638  Multiple Carriers             NaT     Delhi      Cochin      NaT
# 639        Jet Airways             NaT   Kolkata    Banglore      NaT
#
#     arrival_time  duration  total_stops              additional_info  price
# ...

# %%
train
# Out:
#                airline date_of_journey    source destination  dep_time  \
# 0          Jet Airways      2019-06-21    Mumbai   Hyderabad  10:20:00
# 1            Air India      2019-05-18     Delhi      Cochin  09:00:00
# 2            Air India      2019-06-12   Kolkata    Banglore  09:10:00
# 3              Vistara      2019-04-01   Kolkata    Banglore  20:20:00
# 4              Vistara      2019-06-06   Kolkata    Banglore  17:00:00
# ..                 ...             ...       ...         ...       ...
# 635           Air Asia      2019-04-12  Banglore       Delhi  04:55:00
# 636        Jet Airways      2019-05-09   Kolkata    Banglore  09:35:00
# 637             Indigo      2019-05-15  Banglore       Delhi  06:05:00
# 638  Multiple Carriers      2019-05-15     Delhi      Cochin  08:45:00
# 639        Jet Airways      2019-05-21   Kolkata    Banglore  20:00:00
#
#     arrival_time  duration  total_stops              additional_info  price
# ...

# %% [markdown]
# ## 3. High-level Summary of Data

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   airline          640 non-null    object
#  1   date_of_journey  640 non-null    object
#  2   source           640 non-null    object
#  3   destination      640 non-null    object
#  4   dep_time         640 non-null    object
#  5   arrival_time     640 non-null    object
#  6   duration         640 non-null    int64
#  7   total_stops      640 non-null    float64
#  8   additional_info  640 non-null    object
#  9   price            640 non-null    int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 50.1+ KB

# %%
train.describe(include ="number")
# Out:
#           duration  total_stops         price
# count   640.000000   640.000000    640.000000
# mean    639.773438     0.792188   9075.418750
# std     502.047906     0.654060   4328.022872
# min      75.000000     0.000000   1965.000000
# 25%     175.000000     0.000000   5636.250000
# 50%     505.000000     1.000000   8372.000000
# 75%     956.250000     1.000000  12386.750000
# max    2565.000000     3.000000  34273.000000

# %%
(
	train
	.assign(total_stops=train["total_stops"].astype(object))
	.describe(include="O")
)
# Out:
#             airline date_of_journey source destination  dep_time arrival_time  \
# count           640             640    640         640       640          640
# unique            8              40      5           6       165          158
# top     Jet Airways      2019-05-09  Delhi      Cochin  07:10:00     04:25:00
# freq            248              33    263         263        20           36
#
#         total_stops additional_info
# count         640.0             640
# unique          4.0               4
# top             1.0         No Info
# freq          351.0             488

# %% [markdown]
# ## 4. High-Level analysis of missing values

# %%
eda_helper_functions.missing_info(train)
# Out:
# Empty DataFrame
# Columns: [count, percentage]
# Index: []

# %% [markdown]
# ## 5. High-level analysis of outliers

# %%
forest = IsolationForest(n_estimators=10,random_state=42)

# %%
(
    train
    .assign(outlier=forest.fit_predict(train
                                       .drop(columns="price")
                                       .select_dtypes(include="number")))
    .query("outlier == -1")
    # .duration
    # .describe()
)
# Out:
#                airline date_of_journey   source destination  dep_time  \
# 0          Jet Airways      2019-06-21   Mumbai   Hyderabad  10:20:00
# 1            Air India      2019-05-18    Delhi      Cochin  09:00:00
# 2            Air India      2019-06-12  Kolkata    Banglore  09:10:00
# 3              Vistara      2019-04-01  Kolkata    Banglore  20:20:00
# 4              Vistara      2019-06-06  Kolkata    Banglore  17:00:00
# ..                 ...             ...      ...         ...       ...
# 626           Spicejet      2019-05-09   Mumbai   Hyderabad  05:45:00
# 627          Air India      2019-03-21    Delhi      Cochin  19:45:00
# 630          Air India      2019-05-12  Kolkata    Banglore  10:00:00
# 632        Jet Airways      2019-03-24  Kolkata    Banglore  21:10:00
# 633  Multiple Carriers      2019-03-06    Delhi      Cochin  15:05:00
#
#     arrival_time  duration  total_stops               additional_info  price  \
# ...

# %% [markdown]
# ## 6. Pair Plots

# %%
eda_helper_functions.pair_plots(train)
# Out:
# <h2>Pair Plots</h2>

# %% [markdown]
# ## 7. Correlation Analysis

# %%
eda_helper_functions.correlation_heatmap(train)
